# %%
import pandas as pd
df = pd.read_csv('C:\\Users\\Yaswanth\\Desktop\\DSP\\cerealspga05.csv')

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100%_Bran   N    C        70        4    1     130   10.0
# 1                   All-Bran   K    C        70        4    1     260    9.0
# 2  All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
# 3         Cracklin'_Oat_Bran   K    C       110        3    3     140    4.0
# 4      Post_Nat._Raisin_Bran   P    C       120        3    1     200    6.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3    1.00  0.33  68.402973
# 1    7.0       5     320        25      3    1.00  0.33  59.425505
# 2    8.0       0     330        25      3    1.00  0.50  93.704912
# 3   10.0       7     160        25      3    1.00  0.50  40.448772
# 4   11.0      14     260        25      3    1.33  0.67  37.840594

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   74.000000  74.000000  74.000000   74.000000  74.000000  74.000000
# mean   105.540541   2.500000   0.945946  160.675676   2.090541  14.594595
# std     18.442201   1.088546   0.963610   85.188447   2.404002   4.349205
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  131.250000   0.250000  12.000000
# 50%    110.000000   2.000000   1.000000  180.000000   1.500000  14.000000
# 75%    110.000000   3.000000   1.000000  217.500000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  74.000000   74.000000   74.000000  74.000000  74.000000  74.000000
# mean    6.770270   92.675676   28.378378   2.175676   1.027432   0.818243
# std     4.467684   70.578065   22.787104   0.833512   0.151260   0.234914
# ...

# %%
df.isnull().sum()
# Out:
# name        0
# mfr         0
# type        0
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       0
# sugars      0
# potass      0
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib incline
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-378ae482e850> in <module>
#       1 from matplotlib import pyplot as plt
#       2 import seaborn as sns
# ----> 3 get_ipython().run_line_magic('matplotlib', 'incline')
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2325                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2326             with self.builtin_trap:
# -> 2327                 result = fn(*args, **kwargs)
#    2328             return result
#    2329
#
# <decorator-gen-102> in matplotlib(self, line)
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=74, step=1),
#  Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#         'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#         'rating'],
#        dtype='object')]

# %%
df['calories','protein'].plot.hist()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('calories', 'protein')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-0caaea3cd018> in <module>
# ...

# %%
df['calories'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=74, step=1),
#  Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#         'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#         'rating'],
#        dtype='object')]

# %%
df.calories.describe()
# Out:
# count     74.000000
# mean     105.540541
# std       18.442201
# min       50.000000
# 25%      100.000000
# 50%      110.000000
# 75%      110.000000
# max      160.000000
# Name: calories, dtype: float64

# %%
df[df.calories>80 & df.calories < 140].sum()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-7f4b168097d6> in <module>
# ----> 1 df[df.calories>80 & df.calories < 140].sum()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1327
#    1328     def __nonzero__(self):
# -> 1329         raise ValueError(
#    1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df[df.calories > 80 & df.calories < 140]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-88cb63532685> in <module>
# ----> 1 df[df.calories>80 & df.calories < 140]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1327
#    1328     def __nonzero__(self):
# -> 1329         raise ValueError(
#    1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
c1=df[(df.calories > 80) & (df.calories < 140)]

# %%
c1.count()
# Out:
# name        64
# mfr         64
# type        64
# calories    64
# protein     64
# fat         64
# sodium      64
# fiber       64
# carbo       64
# sugars      64
# potass      64
# vitamins    64
# shelf       64
# weight      64
# cups        64
# rating      64
# dtype: int64

# %%
c1['calories'].count()
# Out:
# 64

# %%
df[(df['calories']>80) & (df['calories']<140)].count()
# Out:
# name        64
# mfr         64
# type        64
# calories    64
# protein     64
# fat         64
# sodium      64
# fiber       64
# carbo       64
# sugars      64
# potass      64
# vitamins    64
# shelf       64
# weight      64
# cups        64
# rating      64
# dtype: int64

# %%
df[(df['calories']>80) & (df['calories']<140)]
# Out:
#                      name mfr type  calories  protein  fat  sodium  fiber  \
# 3      Cracklin'_Oat_Bran   K    C       110        3    3     140    4.0
# 4   Post_Nat._Raisin_Bran   P    C       120        3    1     200    6.0
# 5             Raisin_Bran   K    C       120        3    1     210    5.0
# 6       100%_Natural_Bran   Q    C       120        3    5      15    2.0
# 7          Almond_Delight   R    C       110        2    2     200    1.0
# ..                    ...  ..  ...       ...      ...  ...     ...    ...
# 69                Triples   G    C       110        2    1     250    0.0
# 70                   Trix   G    C       110        1    1     140    0.0
# 71             Wheat_Chex   R    C       100        3    1     230    3.0
# 72               Wheaties   G    C       100        3    1     200    3.0
# 73    Wheaties_Honey_Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# ...

# %%
c1['calories'].plot()
# Out:
# <AxesSubplot:>

# %%
c1['calories'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=74, step=1),
#  Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#         'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#         'rating'],
#        dtype='object')]

# %%
df['protein'].plot()
# Out:
# <AxesSubplot:>

# %%
df['protein'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['protein']
# Out:
# 0     4
# 1     4
# 2     4
# 3     3
# 4     3
#      ..
# 69    2
# 70    1
# 71    3
# 72    3
# 73    2
# Name: protein, Length: 74, dtype: int64

# %%
df['calories'].plot()
# Out:
# <AxesSubplot:>

# %%
df['calories'].describe()
# Out:
# count     74.000000
# mean     105.540541
# std       18.442201
# min       50.000000
# 25%      100.000000
# 50%      110.000000
# 75%      110.000000
# max      160.000000
# Name: calories, dtype: float64

# %%
df['protein'].describe()
# Out:
# count    74.000000
# mean      2.500000
# std       1.088546
# min       1.000000
# 25%       2.000000
# 50%       2.000000
# 75%       3.000000
# max       6.000000
# Name: protein, dtype: float64

# %%
df['protein'].plot()
# Out:
# <AxesSubplot:>

# %%
df['protein'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=74, step=1),
#  Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#         'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#         'rating'],
#        dtype='object')]

# %%
df['fat'].describe()
# Out:
# count    74.000000
# mean      0.945946
# std       0.963610
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       5.000000
# Name: fat, dtype: float64

# %%
df['fat'].plot()
# Out:
# <AxesSubplot:>

# %%
df['fat'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['sodium'].describe()
# Out:
# count     74.000000
# mean     160.675676
# std       85.188447
# min        0.000000
# 25%      131.250000
# 50%      180.000000
# 75%      217.500000
# max      320.000000
# Name: sodium, dtype: float64

# %%
df['sodium'].plot()
# Out:
# <AxesSubplot:>

# %%
df['sodium'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['fiber'].describe()
# Out:
# count    74.000000
# mean      2.090541
# std       2.404002
# min       0.000000
# 25%       0.250000
# 50%       1.500000
# 75%       3.000000
# max      14.000000
# Name: fiber, dtype: float64

# %%
df['fiber'].plot()
# Out:
# <AxesSubplot:>

# %%
df['fiber'].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['fiber'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=74, step=1),
#  Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#         'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#         'rating'],
#        dtype='object')]

# %%
df['carbo'].describe()
# Out:
# count    74.000000
# mean     14.594595
# std       4.349205
# min      -1.000000
# 25%      12.000000
# 50%      14.000000
# 75%      17.000000
# max      23.000000
# Name: carbo, dtype: float64

# %%
df['carbo'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['carbo'].plot()
# Out:
# <AxesSubplot:>

# %%
df['sugars'].describe()
# Out:
# count    74.000000
# mean      6.770270
# std       4.467684
# min      -1.000000
# 25%       3.000000
# 50%       6.000000
# 75%      10.750000
# max      15.000000
# Name: sugars, dtype: float64

# %%
df['sugars'].plot()
# Out:
# <AxesSubplot:>

# %%
df['sugars'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['potass'].describe()
# Out:
# count     74.000000
# mean      92.675676
# std       70.578065
# min       -1.000000
# 25%       40.000000
# 50%       90.000000
# 75%      113.750000
# max      330.000000
# Name: potass, dtype: float64

# %%
df['potass'].plot()
# Out:
# <AxesSubplot:>

# %%
df['potass'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=74, step=1),
#  Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#         'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#         'rating'],
#        dtype='object')]

# %%
df['vitamins'].describe()
# Out:
# count     74.000000
# mean      28.378378
# std       22.787104
# min        0.000000
# 25%       25.000000
# 50%       25.000000
# 75%       25.000000
# max      100.000000
# Name: vitamins, dtype: float64

# %%
df['vitamins'].plot()
# Out:
# <AxesSubplot:>

# %%
df['vitamins'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['rating'].describe()
# Out:
# count    74.000000
# mean     42.879265
# std      14.280511
# min      18.042851
# 25%      32.449210
# 50%      40.424490
# 75%      51.401243
# max      93.704912
# Name: rating, dtype: float64

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=74, step=1),
#  Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#         'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#         'rating'],
#        dtype='object')]

# %%
df['rating'].plot()
# Out:
# <AxesSubplot:>

# %%
df['rating'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['vitamins'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['sugars'].plot(kind ='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['sodium'].plot(kind = 'density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['fiber'].plot(kind = 'density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['carbo'].plot(kind = 'density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
plt.boxplot(df['calories'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23d03dd54c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23d03dd5b80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23d03dd5160>],
#  'medians': [<matplotlib.lines.Line2D at 0x23d03de2280>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23d03de25e0>],
#  'means': []}

# %%
plt.boxplot(df['sugars'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23d03e2f910>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23d03e2ffd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23d03e2f5b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x23d03e3a6d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23d03e3aa30>],
#  'means': []}

# %%
df.sugars.describe()
# Out:
# count    74.000000
# mean      6.770270
# std       4.467684
# min      -1.000000
# 25%       3.000000
# 50%       6.000000
# 75%      10.750000
# max      15.000000
# Name: sugars, dtype: float64

# %%
sns.boxplot(df['calories'],orient = 'H', showfliers = True)
# Out:
# C:\Users\Yaswanth\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='calories'>

# %%
sns.boxplot(df['calories'],orient = 'V', showfliers = True)
# Out:
# C:\Users\Yaswanth\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='calories'>

# %%
df['calories'].value_counts().head(3).plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['calories'].value_counts().head(7).plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['calories','ratings'].value_counts().head(3).plot.bar()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('calories', 'ratings')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-97-3d83b8420d89> in <module>
# ...

# %%
df['mfr'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['calories'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.loc[:,['calories','rating']].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.loc[:,['calories','rating']].plot()
# Out:
# <AxesSubplot:>

# %%
df.loc[:,['calories','rating']]
# Out:
#     calories     rating
# 0         70  68.402973
# 1         70  59.425505
# 2         50  93.704912
# 3        110  40.448772
# 4        120  37.840594
# ..       ...        ...
# 69       110  39.106174
# 70       110  27.753301
# 71       100  49.787445
# 72       100  51.592193
# 73       110  36.187559
#
# [74 rows x 2 columns]

# %%
df[:,['protein','rating']].plot.bar(stacked = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-13f330e31d4f> in <module>
# ----> 1 df[:,['protein','rating']].plot.bar(stacked = False)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2893             casted_key = self._maybe_cast_indexer(key)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#    2897                 raise KeyError(key) from err
#
# ...

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=74, step=1),
#  Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#         'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#         'rating'],
#        dtype='object')]

# %%
df.loc[:,['protein','rating']].plot.bar(stacked = False)
# Out:
# <AxesSubplot:>

# %%
df.loc[:,['protein','rating']].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.loc[:,['protein','rating']].plot()
# Out:
# <AxesSubplot:>

# %%
df.loc[:,['protein','rating']]
# Out:
#     protein     rating
# 0         4  68.402973
# 1         4  59.425505
# 2         4  93.704912
# 3         3  40.448772
# 4         3  37.840594
# ..      ...        ...
# 69        2  39.106174
# 70        1  27.753301
# 71        3  49.787445
# 72        3  51.592193
# 73        2  36.187559
#
# [74 rows x 2 columns]

# %%
df.loc[:,['fat','rating']].plot()
# Out:
# <AxesSubplot:>

# %%
df.loc[:,['fat','rating']]
# Out:
#     fat     rating
# 0     1  68.402973
# 1     1  59.425505
# 2     0  93.704912
# 3     3  40.448772
# 4     1  37.840594
# ..  ...        ...
# 69    1  39.106174
# 70    1  27.753301
# 71    1  49.787445
# 72    1  51.592193
# 73    1  36.187559
#
# [74 rows x 2 columns]

# %%
df.loc[:,['sodium','rating']].plot()
# Out:
# <AxesSubplot:>

# %%
df.loc[:,['sodium','rating']]
# Out:
#     sodium     rating
# 0      130  68.402973
# 1      260  59.425505
# 2      140  93.704912
# 3      140  40.448772
# 4      200  37.840594
# ..     ...        ...
# 69     250  39.106174
# 70     140  27.753301
# 71     230  49.787445
# 72     200  51.592193
# 73     200  36.187559
#
# [74 rows x 2 columns]

# %%
df.loc[:,['fiber','rating']].plot()
# Out:
# <AxesSubplot:>

# %%
df.loc[:,['fiber','rating']]
# Out:
#     fiber     rating
# 0    10.0  68.402973
# 1     9.0  59.425505
# 2    14.0  93.704912
# 3     4.0  40.448772
# 4     6.0  37.840594
# ..    ...        ...
# 69    0.0  39.106174
# 70    0.0  27.753301
# 71    3.0  49.787445
# 72    3.0  51.592193
# 73    1.0  36.187559
#
# [74 rows x 2 columns]

# %%
df.loc[:,['carbo','rating']].plot()
# Out:
# <AxesSubplot:>

# %%
df.loc[:,['carbo','rating']]
# Out:
#     carbo     rating
# 0     5.0  68.402973
# 1     7.0  59.425505
# 2     8.0  93.704912
# 3    10.0  40.448772
# 4    11.0  37.840594
# ..    ...        ...
# 69   21.0  39.106174
# 70   13.0  27.753301
# 71   17.0  49.787445
# 72   17.0  51.592193
# 73   16.0  36.187559
#
# [74 rows x 2 columns]

# %%
df.loc[:,['sugars','rating']].plot()
# Out:
# <AxesSubplot:>

# %%
df.loc[:,['sugars','rating']]
# Out:
#     sugars     rating
# 0        6  68.402973
# 1        5  59.425505
# 2        0  93.704912
# 3        7  40.448772
# 4       14  37.840594
# ..     ...        ...
# 69       3  39.106174
# 70      12  27.753301
# 71       3  49.787445
# 72       3  51.592193
# 73       8  36.187559
#
# [74 rows x 2 columns]

# %%
df.loc[:,['vitamins','rating']].plot()
# Out:
# <AxesSubplot:>

# %%
df.loc[:,['vitamins','rating']]
# Out:
#     vitamins     rating
# 0         25  68.402973
# 1         25  59.425505
# 2         25  93.704912
# 3         25  40.448772
# 4         25  37.840594
# ..       ...        ...
# 69        25  39.106174
# 70        25  27.753301
# 71        25  49.787445
# 72        25  51.592193
# 73        25  36.187559
#
# [74 rows x 2 columns]

# %%
# %whos
# Out:
# Variable   Type         Data/Info
# ---------------------------------
# df         DataFrame                             <...>n\n[74 rows x 16 columns]
# pd         module       <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>

# %%
c1.loc[:,['calories','rating']].plot.bar()
# Out:
# <AxesSubplot:>

# %%
c1.loc[:,['calories','rating']].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
c1.loc[:,['calories','rating']].plot()
# Out:
# <AxesSubplot:>

# %%
df.loc[:,['calories','rating'] ].plot()
# Out:
# <AxesSubplot:>

# %%
df.loc[:,['calories','rating'] ].plot.line()
# Out:
# <AxesSubplot:>

# %%
df.cov()
# Out:
#             calories    protein       fat       sodium       fiber  \
# calories  340.114772  -1.438356  7.563865   556.479082  -15.782488
# protein    -1.438356   1.184932  0.150685    -3.698630    1.304795
# fat         7.563865   0.150685  0.928545     1.612366   -0.047094
# sodium    556.479082  -3.698630  1.612366  7257.071455  -13.788041
# fiber     -15.782488   1.304795 -0.047094   -13.788041    5.779224
# carbo      20.564606  -0.678082 -1.467419   134.387264   -3.712107
# sugars     45.125879  -1.856164  0.987412    43.650500   -1.781655
# potass   -206.945576  40.890411  8.776749  -124.572381  153.809219
# vitamins  124.861163   0.342466 -0.499815   701.453165   -1.577194
# shelf       0.520178   0.089041  0.174010    -4.229915    0.563328
# weight      2.117160   0.036781  0.032325     4.023676    0.084263
# cups        0.223565  -0.071164 -0.050781     2.616272   -0.294702
# rating   -187.529398   7.835768 -5.603623  -498.229750   20.606104
#
# ...

# %%
df.corr()
# Out:
#           calories   protein       fat    sodium     fiber     carbo  \
# calories  1.000000 -0.071648  0.425627  0.354206 -0.355982  0.256388
# protein  -0.071648  1.000000  0.143655 -0.039885  0.498610 -0.143227
# fat       0.425627  0.143655  1.000000  0.019642 -0.020329 -0.350141
# sodium    0.354206 -0.039885  0.019642  1.000000 -0.067327  0.362717
# fiber    -0.355982  0.498610 -0.020329 -0.067327  1.000000 -0.355039
# carbo     0.256388 -0.143227 -0.350141  0.362717 -0.355039  1.000000
# sugars    0.547685 -0.381669  0.229358  0.114690 -0.165885 -0.340435
# potass   -0.158991  0.532237  0.129051 -0.020719  0.906521 -0.359012
# vitamins  0.297116  0.013806 -0.022762  0.361351 -0.028791  0.259354
# shelf     0.033840  0.098137  0.216651 -0.059572  0.281135 -0.104785
# weight    0.758956  0.223383  0.221775  0.312261  0.231728  0.151341
# cups      0.051604 -0.278296 -0.224333  0.130735 -0.521842  0.357282
# rating   -0.712054  0.504070 -0.407215 -0.409548  0.600230  0.055804
#
# ...

# %%
df.loc[:,['calories','fiber','sugars','protein']].cov()
# Out:
#             calories      fiber     sugars   protein
# calories  340.114772 -15.782488  45.125879 -1.438356
# fiber     -15.782488   5.779224  -1.781655  1.304795
# sugars     45.125879  -1.781655  19.960200 -1.856164
# protein    -1.438356   1.304795  -1.856164  1.184932

# %%
df.cov()
# Out:
#             calories    protein       fat       sodium       fiber  \
# calories  340.114772  -1.438356  7.563865   556.479082  -15.782488
# protein    -1.438356   1.184932  0.150685    -3.698630    1.304795
# fat         7.563865   0.150685  0.928545     1.612366   -0.047094
# sodium    556.479082  -3.698630  1.612366  7257.071455  -13.788041
# fiber     -15.782488   1.304795 -0.047094   -13.788041    5.779224
# carbo      20.564606  -0.678082 -1.467419   134.387264   -3.712107
# sugars     45.125879  -1.856164  0.987412    43.650500   -1.781655
# potass   -206.945576  40.890411  8.776749  -124.572381  153.809219
# vitamins  124.861163   0.342466 -0.499815   701.453165   -1.577194
# shelf       0.520178   0.089041  0.174010    -4.229915    0.563328
# weight      2.117160   0.036781  0.032325     4.023676    0.084263
# cups        0.223565  -0.071164 -0.050781     2.616272   -0.294702
# rating   -187.529398   7.835768 -5.603623  -498.229750   20.606104
#
# ...

# %%
df.loc[:,['calories','fiber','sugars','protein']].cov(df['rating'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-94fde01f06ab> in <module>
# ----> 1 a=df.loc[:,['calories','fiber','sugars','protein']].cov(df['rating'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in cov(self, min_periods, ddof)
#    8270
#    8271         if notna(mat).all():
# -> 8272             if min_periods is not None and min_periods > len(mat):
#    8273                 base_cov = np.empty((mat.shape[1], mat.shape[1]))
#    8274                 base_cov.fill(np.nan)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1327
#    1328     def __nonzero__(self):
# -> 1329         raise ValueError(
#    1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ...

# %%
df.loc[:,['calories','fiber','sugars','protein','rating']].cov()
# Out:
#             calories      fiber     sugars   protein      rating
# calories  340.114772 -15.782488  45.125879 -1.438356 -187.529398
# fiber     -15.782488   5.779224  -1.781655  1.304795   20.606104
# sugars     45.125879  -1.781655  19.960200 -1.856164  -48.490594
# protein    -1.438356   1.304795  -1.856164  1.184932    7.835768
# rating   -187.529398  20.606104 -48.490594  7.835768  203.932984

# %%
import scipy.stats as st

# %%
Ktype = df.query('mfr== "k"')['rating']

# %%
import matplotlib.pyplib as ppl
ppl.df['mfr'].plot.hist()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-19-c9db17f6801a> in <module>
# ----> 1 import matplotlib.pyplib as ppl
#       2 ppl.df['mfr'].plot.hist()
#
# ModuleNotFoundError: No module named 'matplotlib.pyplib'

# %%
df['mfr'].value_counts().head(5).plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['mfr'].value_counts().head(5).plot.bar()
# Out:
# <AxesSubplot:>

# %%
gtype= df.query('mfr == "g"')['rating']
ktype=  df.query('mfr == "K"')['rating']

# %%
results = st.ttest_ind(ktype,gtype,equal_var = True)

# %%
results
# Out:
# Ttest_indResult(statistic=nan, pvalue=nan)

# %%
gtype= df.query('mfr == "n"')['rating']
ktype=  df.query('mfr == "K"')['rating']
display(results)
# Out:
# Ttest_indResult(statistic=nan, pvalue=nan)

# %%
df_type_c = df[df['type'] == 'C']

# %% [markdown]
# # Under sampling

# %%
df_type_c.count()
# Out:
# name        71
# mfr         71
# type        71
# calories    71
# protein     71
# fat         71
# sodium      71
# fiber       71
# carbo       71
# sugars      71
# potass      71
# vitamins    71
# shelf       71
# weight      71
# cups        71
# rating      71
# dtype: int64

# %%
df_type_H = df[df['type']=='H']

# %%
df_type_H.count()
# Out:
# name        3
# mfr         3
# type        3
# calories    3
# protein     3
# fat         3
# sodium      3
# fiber       3
# carbo       3
# sugars      3
# potass      3
# vitamins    3
# shelf       3
# weight      3
# cups        3
# rating      3
# dtype: int64

# %%
df_type_c.shape
# Out:
# (71, 16)

# %%
df_type_H.shape
# Out:
# (3, 16)

# %%
df['type'].value_counts()
# Out:
# C    71
# H     3
# Name: type, dtype: int64

# %%
df_type_c.value_counts()
# Out:
# name                    mfr  type  calories  protein  fat  sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  rating
# Wheaties_Honey_Gold     G    C     110       2        1    200     1.0    16.0   8       60      25        1      1.00    0.75  36.187559    1
# Frosted_Mini-Wheats     K    C     100       3        0    0       3.0    14.0   7       100     25        2      1.00    0.80  58.345141    1
# Cracklin'_Oat_Bran      K    C     110       3        3    140     4.0    10.0   7       160     25        3      1.00    0.50  40.448772    1
# Crispix                 K    C     110       2        0    220     1.0    21.0   3       30      25        3      1.00    1.00  46.895644    1
# Crispy_Wheat_&_Raisins  G    C     100       2        1    140     2.0    11.0   10      120     25        3      1.00    0.75  36.176196    1
# ...

# %%
df_type_H.value_counts()
# Out:
# name                    mfr  type  calories  protein  fat  sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  rating
# Quaker_Oatmeal          Q    H     100       5        2    0       2.7    -1.0   -1       110    0         1      1.0     0.67  50.828392    1
# Maypo                   A    H     100       4        1    0       0.0     16.0   3       95     25        2      1.0     1.00  54.850917    1
# Cream_of_Wheat_(Quick)  N    H     100       3        0    80      1.0     21.0   0      -1      0         2      1.0     1.00  64.533816    1
# dtype: int64

# %%
df_type_C_under = df_type_c.sample(df_type_H.value_counts())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-4d5daf34bd5b> in <module>
# ----> 1 df_type_C_under = df_type_c.sample(df_type_H.value_counts())
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in sample(self, n, frac, replace, weights, random_state, axis)
#    4978                 "upsampling the population `frac` > 1."
#    4979             )
# -> 4980         elif n is not None and frac is None and n % 1 != 0:
#    4981             raise ValueError("Only integers accepted as `n` values")
#    4982         elif n is None and frac is not None:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1327
#    1328     def __nonzero__(self):
# -> 1329         raise ValueError(
#    1330             f"The truth value of a {type(self).__name__} is ambiguous. "
# ...

# %%
 count_typeC = df[df['type']=='C'].value_counts()

# %%
count_typeC
# Out:
# name                    mfr  type  calories  protein  fat  sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  rating
# Wheaties_Honey_Gold     G    C     110       2        1    200     1.0    16.0   8       60      25        1      1.00    0.75  36.187559    1
# Frosted_Mini-Wheats     K    C     100       3        0    0       3.0    14.0   7       100     25        2      1.00    0.80  58.345141    1
# Cracklin'_Oat_Bran      K    C     110       3        3    140     4.0    10.0   7       160     25        3      1.00    0.50  40.448772    1
# Crispix                 K    C     110       2        0    220     1.0    21.0   3       30      25        3      1.00    1.00  46.895644    1
# Crispy_Wheat_&_Raisins  G    C     100       2        1    140     2.0    11.0   10      120     25        3      1.00    0.75  36.176196    1
# ...

# %%
df[df['type']=='C'].value_counts()
# Out:
# name                    mfr  type  calories  protein  fat  sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  rating
# Wheaties_Honey_Gold     G    C     110       2        1    200     1.0    16.0   8       60      25        1      1.00    0.75  36.187559    1
# Frosted_Mini-Wheats     K    C     100       3        0    0       3.0    14.0   7       100     25        2      1.00    0.80  58.345141    1
# Cracklin'_Oat_Bran      K    C     110       3        3    140     4.0    10.0   7       160     25        3      1.00    0.50  40.448772    1
# Crispix                 K    C     110       2        0    220     1.0    21.0   3       30      25        3      1.00    1.00  46.895644    1
# Crispy_Wheat_&_Raisins  G    C     100       2        1    140     2.0    11.0   10      120     25        3      1.00    0.75  36.176196    1
# ...

# %%
count_typeH = df[df['type']=='H'].value_counts()
count_typeH
# Out:
# name                    mfr  type  calories  protein  fat  sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  rating
# Quaker_Oatmeal          Q    H     100       5        2    0       2.7    -1.0   -1       110    0         1      1.0     0.67  50.828392    1
# Maypo                   A    H     100       4        1    0       0.0     16.0   3       95     25        2      1.0     1.00  54.850917    1
# Cream_of_Wheat_(Quick)  N    H     100       3        0    80      1.0     21.0   0      -1      0         2      1.0     1.00  64.533816    1
# dtype: int64

# %%
df_type_H_mul = df[df['type']=='H']*13

# %%
df_type_H_mul
# Out:
#                                                  name            mfr  \
# 22  Cream_of_Wheat_(Quick)Cream_of_Wheat_(Quick)Cr...  NNNNNNNNNNNNN
# 44  MaypoMaypoMaypoMaypoMaypoMaypoMaypoMaypoMaypoM...  AAAAAAAAAAAAA
# 55  Quaker_OatmealQuaker_OatmealQuaker_OatmealQuak...  QQQQQQQQQQQQQ
#
#              type  calories  protein  fat  sodium  fiber  carbo  sugars  \
# 22  HHHHHHHHHHHHH      1300       39    0    1040   13.0  273.0       0
# 44  HHHHHHHHHHHHH      1300       52   13       0    0.0  208.0      39
# 55  HHHHHHHHHHHHH      1300       65   26       0   35.1  -13.0     -13
#
#     potass  vitamins  shelf  weight   cups      rating
# 22     -13         0     26    13.0  13.00  838.939608
# 44    1235       325     26    13.0  13.00  713.061921
# 55    1430         0     13    13.0   8.71  660.769096

# %%
df_type_H_mul = df[df['type']=='H'].value_counts * 13
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-789c67b284af> in <module>
# ----> 1 df_type_H_mul = df[df['type']=='H'].value_counts * 13
#
# TypeError: unsupported operand type(s) for *: 'method' and 'int'

# %%
df_type_C_under = df[df['type']=='C'].sample(3)

# %%
df_type_C_under
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 49          Nutri-grain_Wheat   K    C        90        3    0     170    3.0
# 36           Honey_Graham_Ohs   Q    C       120        1    2     220    1.0
# 62  Shredded_Wheat_spoon_size   N    C        90        3    0       0    3.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 49   18.0       2      90        25      3     1.0  1.00  59.642837
# 36   12.0      11      45        25      2     1.0  1.00  21.871292
# 62   20.0       0     120         0      1     1.0  0.67  72.801787

# %%
type_C ,type_H = df['type'].value_counts()
type_C,type_H
# Out:
# (71, 3)

# %%
df_type_C_under = df[df['type']=='C'].sample(type_H)

# %%
df_type_C_under
# Out:
#                 name mfr type  calories  protein  fat  sodium  fiber  carbo  \
# 47  Nut&Honey_Crunch   K    C       120        2    1     190    0.0   15.0
# 7     Almond_Delight   R    C       110        2    2     200    1.0   14.0
# 11         Bran_Chex   R    C        90        2    1     200    4.0   15.0
#
#     sugars  potass  vitamins  shelf  weight  cups     rating
# 47       9      40        25      2     1.0  0.67  29.924285
# 7        8      -1        25      3     1.0  0.75  34.384843
# 11       6     125        25      1     1.0  0.67  49.120253

# %%
df_type_under = df_type_H + df_type_C_under

# %%
df_type_under
# Out:
#    name  mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  \
# 7   NaN  NaN  NaN       NaN      NaN  NaN     NaN    NaN    NaN     NaN
# 11  NaN  NaN  NaN       NaN      NaN  NaN     NaN    NaN    NaN     NaN
# 22  NaN  NaN  NaN       NaN      NaN  NaN     NaN    NaN    NaN     NaN
# 44  NaN  NaN  NaN       NaN      NaN  NaN     NaN    NaN    NaN     NaN
# 47  NaN  NaN  NaN       NaN      NaN  NaN     NaN    NaN    NaN     NaN
# 55  NaN  NaN  NaN       NaN      NaN  NaN     NaN    NaN    NaN     NaN
#
#     potass  vitamins  shelf  weight  cups  rating
# 7      NaN       NaN    NaN     NaN   NaN     NaN
# 11     NaN       NaN    NaN     NaN   NaN     NaN
# 22     NaN       NaN    NaN     NaN   NaN     NaN
# 44     NaN       NaN    NaN     NaN   NaN     NaN
# 47     NaN       NaN    NaN     NaN   NaN     NaN
# 55     NaN       NaN    NaN     NaN   NaN     NaN

# %%
df_type_C_under
# Out:
#                 name mfr type  calories  protein  fat  sodium  fiber  carbo  \
# 47  Nut&Honey_Crunch   K    C       120        2    1     190    0.0   15.0
# 7     Almond_Delight   R    C       110        2    2     200    1.0   14.0
# 11         Bran_Chex   R    C        90        2    1     200    4.0   15.0
#
#     sugars  potass  vitamins  shelf  weight  cups     rating
# 47       9      40        25      2     1.0  0.67  29.924285
# 7        8      -1        25      3     1.0  0.75  34.384843
# 11       6     125        25      1     1.0  0.67  49.120253

# %%
df_type_H
# Out:
#                       name mfr type  calories  protein  fat  sodium  fiber  \
# 22  Cream_of_Wheat_(Quick)   N    H       100        3    0      80    1.0
# 44                   Maypo   A    H       100        4    1       0    0.0
# 55          Quaker_Oatmeal   Q    H       100        5    2       0    2.7
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 22   21.0       0      -1         0      2     1.0  1.00  64.533816
# 44   16.0       3      95        25      2     1.0  1.00  54.850917
# 55   -1.0      -1     110         0      1     1.0  0.67  50.828392

# %%
df_type_under = pd.concat([df_type_H,df_type_C_under], axis = 0)

# %%
df_type_under
# Out:
#                       name mfr type  calories  protein  fat  sodium  fiber  \
# 22  Cream_of_Wheat_(Quick)   N    H       100        3    0      80    1.0
# 44                   Maypo   A    H       100        4    1       0    0.0
# 55          Quaker_Oatmeal   Q    H       100        5    2       0    2.7
# 47        Nut&Honey_Crunch   K    C       120        2    1     190    0.0
# 7           Almond_Delight   R    C       110        2    2     200    1.0
# 11               Bran_Chex   R    C        90        2    1     200    4.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 22   21.0       0      -1         0      2     1.0  1.00  64.533816
# 44   16.0       3      95        25      2     1.0  1.00  54.850917
# 55   -1.0      -1     110         0      1     1.0  0.67  50.828392
# 47   15.0       9      40        25      2     1.0  0.67  29.924285
# 7    14.0       8      -1        25      3     1.0  0.75  34.384843
# ...

# %%
df_type_under.shape
# Out:
# (6, 16)

# %%
df_type_under.value_counts()
# Out:
# name                    mfr  type  calories  protein  fat  sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  rating
# Quaker_Oatmeal          Q    H     100       5        2    0       2.7    -1.0   -1       110    0         1      1.0     0.67  50.828392    1
# Nut&Honey_Crunch        K    C     120       2        1    190     0.0     15.0   9       40     25        2      1.0     0.67  29.924285    1
# Maypo                   A    H     100       4        1    0       0.0     16.0   3       95     25        2      1.0     1.00  54.850917    1
# Cream_of_Wheat_(Quick)  N    H     100       3        0    80      1.0     21.0   0      -1      0         2      1.0     1.00  64.533816    1
# Bran_Chex               R    C     90        2        1    200     4.0     15.0   6       125    25        1      1.0     0.67  49.120253    1
# ...

# %%
df_type_under.type.value_counts()
# Out:
# C    3
# H    3
# Name: type, dtype: int64

# %% [markdown]
# # over sampling

# %%
type_C,type_H
# Out:
# (71, 3)

# %%
# %whos
# Out:
# Variable          Type               Data/Info
# ----------------------------------------------
# Gtype             Series             Series([], Name: rating, dtype: float64)
# Ktype             Series             Series([], Name: rating, dtype: float64)
# count_typeC       Series             name                    m<...>nLength: 71, dtype: int64
# count_typeH       Series             name                    m<...>533816    1\ndtype: int64
# df                DataFrame                                   <...>n\n[74 rows x 16 columns]
# df_type_C_under   DataFrame                          name mfr <...>   1.0  0.67  49.120253
# df_type_H         DataFrame                                nam<...>   1.0  0.67  50.828392
# df_type_H_mul     DataFrame                                   <...>13.0   8.71  660.769096
# df_type_c         DataFrame                                   <...>n\n[71 rows x 16 columns]
# ...

# %%
df[df['type']=='H']
# Out:
#                       name mfr type  calories  protein  fat  sodium  fiber  \
# 22  Cream_of_Wheat_(Quick)   N    H       100        3    0      80    1.0
# 44                   Maypo   A    H       100        4    1       0    0.0
# 55          Quaker_Oatmeal   Q    H       100        5    2       0    2.7
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 22   21.0       0      -1         0      2     1.0  1.00  64.533816
# 44   16.0       3      95        25      2     1.0  1.00  54.850917
# 55   -1.0      -1     110         0      1     1.0  0.67  50.828392

# %%
df[df['type']=='H'].sample(1)
# Out:
#      name mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  \
# 44  Maypo   A    H       100        4    1       0    0.0   16.0       3
#
#     potass  vitamins  shelf  weight  cups     rating
# 44      95        25      2     1.0   1.0  54.850917

# %%
df_type_H_over=df[df['type']=='H'].sample(type_C,replace=True)

# %%
df_type_over = pd.concat([df_type_c,df_type_H_over], axis = 0)
print(df_type_over.type.value_counts())
print(df_type_under.type.value_counts())
# Out:
# H    71
# C    71
# Name: type, dtype: int64
# C    3
# H    3
# Name: type, dtype: int64
